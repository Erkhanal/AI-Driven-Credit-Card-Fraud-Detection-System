# %% [markdown]
# # **Credit Card Fraud Detection System**

# %% [markdown]
# ### **1. Introduction:**

# %% [markdown]
# <div align="justify"> Fraudulent credit card transactions pose a major risk to financial institutions, leading to financial losses, decreased institution’s trust, and reduced customer satisfaction. With the exponential rise in digital payment channels, detecting fraud has become an important priority for banks and financial institutions.</div><br>
#
# <div align="justify">Machine learning offers a powerful solution to detect and prevent fraudulent transactions. By automating fraud detection processes, banks can reduce the need for manual reviews, avoid costly chargebacks, prevent legitimate transaction denials, and enhance the overall customer experience.</div><br>
#
# <div align="justify">This capstone project explores the use of machine learning models to predict fraudulent transactions in credit cards. By analyzing a publicly available dataset from a collaboration between Worldline and the Machine Learning Group, we aim to build a robust fraud detection model capable of identifying fraudulent activities with high precision.</div>

# %% [markdown]
# ### **2. Business Problem Overview:**

# %% [markdown]
# <div align="justify">  For many banks, customer retention and profitability are key priorities. Fraudulent credit card transactions present a major challenge to this objective, as they lead to significant financial losses, erosion of customer trust, and damage to brand reputation.</div><br>
#
# <div align="justify">According to the Nilson report, global banking fraud was estimated to reach $30 billion by 2020. The rise of digital payment platforms has significantly increased the opportunities for fraudsters to exploit weaknesses in the banking system. Therefore, banks and financial institutions must implement proactive and efficient fraud detection mechanisms.</div>

# %% [markdown]
# ### **3. Objective:**

# %% [markdown]
# <div align="justify"> The main objective of this project is to build machine learning models that will help banks and financial institutions to detect fraud with greater accuracy. For this we will use various machine learning techniques and evaluate the model performance.</div>

# %% [markdown]
# ### **4. Analysis Approach:**

# %% [markdown]
# <div align="justify"> To tackle this problem effectively, I have established a structured data analysis approach.</br></div>
#
# 1. Reading and Understanding the Data
# 2. Data Preprocessing
# 3. Exploratory Data Analytics (EDA)
# 4. Train/Test Split
# 5. Model Building and Hyperparameter Tuning
# 6. Model Evaluation and Selection

# %% [markdown]
# ### **4.1 Reading and Understanding the Data:**
# <div align="justify">
# It includes data loading and analyzing to understand the data structure, types of variables, target variable distribution, understanding the nature of the features and their relevance to the problem, identifying any patterns or trends that might help in predicting fraudulent transactions.</div><br>
#
# ### **4.2 Data Preprocessing:**
# <div align="justify">It includes checking data type, cleaning, and preparing the data for analysis, handling missing values, encoding categorical variables, dropping unnecessary columns, and standardizing data.</div><br>
#
# ### **4.3 Exploratory Data Analytics (EDA):**
# <div align="justify">EDA will be performed to uncover deeper insights and relationships within the data. Mainly the following analyses will be conducted:<br>
#
# **Univariate Analysis:** Understanding the distribution of individual features.<br>
#
# **Bivariate Analysis:** Analyzing relationships between pairs of features and the target variable.<br>
#
# **Imbalanced Data Check:** Identifying the imbalance between fraudulent and non-fraudulent transactions.<br>
#
# **Skewness Check:** Checking for any skewed distributions that might affect model performance.<br></div>
#
# ### **4.4 Train/Test Split:**
# <div align="justify">After completing the EDA, dataset will be split into training and testing sets. To ensure the model performs well on unseen data, stratified train-test splitting will be applied. This helps maintain the proportion of fraudulent to non-fraudulent transactions in both the training and testing datasets.<br></div>
#
# <div align="justify">Since the dataset is highly imbalanced, specific resampling techniques such as Random Over Sampling, SMOTE (Synthetic Minority Over-sampling Technique), and ADASYN (Adaptive Synthetic Sampling) are applied to balance the dataset.<br></div>
#
# ### **4.5 Model Building and Hyperparameter Tuning:**
# <div align="justify">In this phase where we will experiment with different machine learning models and adjust their hyperparameters to find the most accurate model for predicting fraudulent transactions. <br></div>
#
# <div align="justify">Various machine learning models are trained on both imbalanced and balanced datasets, using various resampling techniques (Random Over Sampling, SMOTE, and ADASYN) to compare their performance. Hyperparameter tuning is conducted to optimize the models, using methods such as grid search and random search, in conjunction with stratified k-fold cross-validation.<br></div>
#
# ### **4.6 Model Evaluation and Model Selection:**
# <div align="justify">It includes evaluating, validating, and comparing the performance of various machine learning models and analyzing which model provides better insights into fraud transactions. The best-performing model will be selected based on the evaluation metrics such as precision, recall, and F1-score, including the ROC-AUC score and the confusion matrix. Key considerations include:<br>
#
# **Model Accuracy:** How well the model classifies fraudulent transactions.<br>
#
# **Model Stability:** Consistent performance across multiple folds of cross-validation.<br>
#
# **Feature Importance:** Identifying the most influential features for predicting fraud.</div>

# %% [markdown]
# ### Python Code Implementation:

# %% [markdown]
# #### To Import Required Libraries:

# %%
# To import all the required libraries:
# For numerical operations:
import numpy as np

# For data manipulation and analysis:
import pandas as pd

# For plotting graphs and visualizations:
import matplotlib.pyplot as plt

# For statistical data visualization:
import seaborn as sns

# For handling warnings:
import warnings

# To ignore warnings to keep the output clean:
warnings.filterwarnings("ignore")

# To import libraries for date and time manipulation:
from datetime import datetime, timedelta

# To set display options for pandas dataframe:
pd.options.display.float_format = '{:.4f}'.format  # To format float numbers to 4 decimal places
plt.rcParams['figure.figsize'] = [12, 8]  # To set the default figure size for plots
pd.set_option('display.max_columns', 500)  # To display up to 500 columns in the dataframe
pd.set_option('display.max_colwidth', None)

# To configure seaborn for better aesthetics:
sns.set(style='darkgrid')

# To import additional matplotlib functionality:
import matplotlib.ticker as plticker

# To enable inline plotting for Jupyter notebooks:
# %matplotlib inline

# To import all the required libraries and dependencies for machine learning:
# For splitting data into training and testing sets:
from sklearn.model_selection import train_test_split

# For feature scaling:
from sklearn.preprocessing import StandardScaler

# For logistic regression model:
from sklearn.linear_model import LogisticRegression

# For hyperparameter tuning:
from sklearn.model_selection import GridSearchCV

# For k-fold cross-validation:
from sklearn.model_selection import KFold

# For calculating ROC AUC score:
from sklearn.metrics import roc_auc_score

# For decision tree classifier:
from sklearn.tree import DecisionTreeClassifier

# For random forest classifier:
from sklearn.ensemble import RandomForestClassifier

# For AdaBoost classifier:
from sklearn.ensemble import AdaBoostClassifier

# For various evaluation metrics:
from sklearn import metrics

# For statistical models:
import statsmodels.api as sm

# For saving and loading models:
import pickle

# For garbage collection:
import gc

# For support vector machine:
from sklearn import svm

# For XGBoost classifier:
from xgboost import XGBClassifier

# For additional XGBoost functionalities:
import xgboost as xgb

# For calculating accuracy:
from sklearn.metrics import accuracy_score

# For ROC and precision-recall curves:
from sklearn.metrics import roc_curve, roc_auc_score, precision_recall_curve, average_precision_score

# For classification report:
from sklearn.metrics import classification_report

# For confusion matrix:
from sklearn.metrics import confusion_matrix

# %% [markdown]
# ### Data Reading And Understanding:

# %%
# To define file path:
path = r'C:\Users\shish\Desktop\Capstone\creditcard.csv'

# %%
# Reading the Credit Card file:
df_card = pd.read_csv(path)

# To display the first few rows of the dataframe:
df_card.head()
# Out:
#     Time      V1      V2     V3      V4      V5      V6      V7      V8  \
# 0 0.0000 -1.3598 -0.0728 2.5363  1.3782 -0.3383  0.4624  0.2396  0.0987
# 1 0.0000  1.1919  0.2662 0.1665  0.4482  0.0600 -0.0824 -0.0788  0.0851
# 2 1.0000 -1.3584 -1.3402 1.7732  0.3798 -0.5032  1.8005  0.7915  0.2477
# 3 1.0000 -0.9663 -0.1852 1.7930 -0.8633 -0.0103  1.2472  0.2376  0.3774
# 4 2.0000 -1.1582  0.8777 1.5487  0.4030 -0.4072  0.0959  0.5929 -0.2705
#
#        V9     V10     V11     V12     V13     V14     V15     V16     V17  \
# 0  0.3638  0.0908 -0.5516 -0.6178 -0.9914 -0.3112  1.4682 -0.4704  0.2080
# 1 -0.2554 -0.1670  1.6127  1.0652  0.4891 -0.1438  0.6356  0.4639 -0.1148
# 2 -1.5147  0.2076  0.6245  0.0661  0.7173 -0.1659  2.3459 -2.8901  1.1100
# 3 -1.3870 -0.0550 -0.2265  0.1782  0.5078 -0.2879 -0.6314 -1.0596 -0.6841
# 4  0.8177  0.7531 -0.8228  0.5382  1.3459 -1.1197  0.1751 -0.4514 -0.2370
#
#       V18     V19     V20     V21     V22     V23     V24     V25     V26  \
# ...

# %%
# To display the dimensions of the credit card dataset:
df_card.shape
# Out:
# (284807, 31)

# %% [markdown]
# #### Observations: Our dataset has 284,807 entries and 31 columns.

# %%
# To display a statistical summary of the credit card dataset:
df_card.describe()
# Out:
#              Time          V1          V2          V3          V4          V5  \
# count 284807.0000 284807.0000 284807.0000 284807.0000 284807.0000 284807.0000
# mean   94813.8596      0.0000      0.0000     -0.0000      0.0000      0.0000
# std    47488.1460      1.9587      1.6513      1.5163      1.4159      1.3802
# min        0.0000    -56.4075    -72.7157    -48.3256     -5.6832   -113.7433
# 25%    54201.5000     -0.9204     -0.5985     -0.8904     -0.8486     -0.6916
# 50%    84692.0000      0.0181      0.0655      0.1798     -0.0198     -0.0543
# 75%   139320.5000      1.3156      0.8037      1.0272      0.7433      0.6119
# max   172792.0000      2.4549     22.0577      9.3826     16.8753     34.8017
#
#                V6          V7          V8          V9         V10         V11  \
# count 284807.0000 284807.0000 284807.0000 284807.0000 284807.0000 284807.0000
# mean       0.0000     -0.0000      0.0000     -0.0000      0.0000      0.0000
# ...

# %%
# To display the summary information of the credit card dataset:
df_card.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %% [markdown]
# ### Data Cleaning:

# %%
# To calculate the percentage of missing values in the dataframe and display the top entries:
df_null = df_card.isnull().mean() * 100
df_null.sort_values(ascending=False).head()
# Out:
# Time     0.0000
# V16      0.0000
# Amount   0.0000
# V28      0.0000
# V27      0.0000
# dtype: float64

# %% [markdown]
# #### Observations: We discovered that the dataset contains no missing values, so there's no need for null value treatment.

# %%
# To check the data types of columns in the dataframe:
df_card.dtypes
# Out:
# Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class       int64
# dtype: object

# %% [markdown]
# #### Observations: All the columns have uniform data types, so no data type conversion is necessary.

# %% [markdown]
# ### Data Visualization:

# %% [markdown]
# #### Distribution of Fraudulent Variable:

# %%
# To set up the figure size:
plt.figure(figsize=(10, 6))

# To create the first subplot for bar plot:
plt.subplot(121)
plt.title('Fraudulent Transactions Distribution', fontweight='bold', fontsize=14)
ax = df_card['Class'].value_counts().plot(kind='bar', color=['lightgreen', 'green'])

# To add percentage labels on top of each bar:
total = float(len(df_card))
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width()/2.,
            height + 3,
            '{:.2f}%'.format((height/total)*100),
            ha="center")

# To create the second subplot for pie chart:
plt.subplot(122)
df_card['Class'].value_counts().plot.pie(autopct='%1.2f%%', colors=['lightblue', 'red'])

# To display the plots:
plt.tight_layout()
plt.show()

# %%
# To calculate the class counts:
classes = df_card['Class'].value_counts()

# To calculate the percentage shares:
normal_share = classes[0] / df_card['Class'].count() * 100
fraud_share = classes[1] / df_card['Class'].count() * 100

# To print the results:
print("Percentage share of normal transactions: {:.2f}%".format(normal_share))
print("Percentage share of fraudulent transactions: {:.2f}%".format(fraud_share))
# Out:
# Percentage share of normal transactions: 99.83%
# Percentage share of fraudulent transactions: 0.17%

# %% [markdown]
# #### Observations: In our case, using accuracy to evaluate our classification algorithm isn't a good idea. If we depend on only on accuracy, the model might just predict everything as 0 (Non-Fraud), which could be misleading.

# %% [markdown]
# #### Box Plot of Amount for Normal and Fraudulent Transactions:

# %%
# To set up the figure size and style:
plt.figure(figsize=(12, 8))
sns.set(style="whitegrid", palette="Set2")

# To create a box plot:
sns.boxplot(x='Class', y='Amount', hue='Class', data=df_card, showfliers=False)

# To customize x-axis labels:
plt.xticks(range(2), ['Normal', 'Fraudulent'])
plt.xlabel("Class", fontsize=14, fontweight='bold')

# To set plot title:
plt.title('Box Plot of Amount for Normal and Fraudulent Transactions', fontsize=14, fontweight='bold')

# To display legend with labels:
plt.legend(title='Class', loc='upper right')

# To display plot:
plt.show()

# %% [markdown]
# #### KDE Plot for Normal and Fraudulent Transactions:

# %%
# To set the figure size:
plt.rcParams['figure.figsize'] = [12, 8]

# To create KDE plots for both classes:
sns.kdeplot(df_card.loc[df_card['Class'] == 0, 'Amount'], label='Non Fraud', shade=True)
sns.kdeplot(df_card.loc[df_card['Class'] == 1, 'Amount'], label='Fraud', shade=True)

# To set plot title and labels:
plt.title('Distribution of Amount by Target Value', fontsize=14, fontweight='bold')
plt.xlabel('Amount', fontsize=14)
plt.ylabel('Density', fontsize=14)

# To display legend:
plt.legend()

# To display plot:
plt.show()

# %% [markdown]
# #### Observations: The amount involved in fraudulent transactions is much higher compared to non-fraudulent transactions.

# %% [markdown]
# #### Time Distribution plot:

# %%
# To set up figure size:
plt.figure(figsize=(12, 8))

# To set plot title:
plt.title('Distribution of Transaction Time', fontsize=14, fontweight='bold')

# To plot distribution of transaction times:
# To convert transaction times to hours and plot distribution:
sns.distplot(df_card['Time'].values / (60 * 60), color='blue')

# To display the plot:
plt.show()

# %%
# To sort Fraud and non-Fraud transactions:

# To select non-fraudulent transactions:
df_nonfraud = df_card[df_card.Class == 0]

# To select fraudulent transactions:
df_fraud = df_card[df_card.Class == 1]

# %% [markdown]
# #### Scatter Plot Between Time Vs Amount:

# %%
# To set a figure size:
fig = plt.figure(figsize=(12, 8))

# Scatter plot for non-fraudulent transactions:
plt.scatter(df_nonfraud.Amount, df_nonfraud.Time.values/(60*60), alpha=0.5, label='Non Fraud', color='lightblue')

# Scatter plot for fraudulent transactions:
plt.scatter(df_fraud.Amount, df_fraud.Time.values/(60*60), alpha=1, label='Fraud', color='lightgreen')

# To set labels and title:
plt.xlabel('Amount', fontsize=14)
plt.ylabel('Time', fontsize=14)
plt.title('Scatter plot between Amount and Time', fontsize=14)

# To show legend:
plt.legend()

# To display the plot:
plt.show()

# %% [markdown]
# #### High Value Transactions (USD 200 to USD 2000) Plot:

# %%
# To define bins for the histogram:
bins = np.linspace(200, 2000, 100)

# To plot histogram for non-fraudulent transactions:
plt.hist(df_nonfraud.Amount, bins, alpha=0.7, density=True, label='Non-Fraud', color='blue')

# To plot histogram for fraudulent transactions:
plt.hist(df_fraud.Amount, bins, alpha=0.7, density=True, label='Fraud', color='red')

# To add legend:
plt.legend(loc='upper right')

# To set title and labels:
plt.title("Amount by percentage of transactions (transactions 200 to 2000)", fontsize=14)
plt.xlabel("Transaction amount (USD)", fontsize=14)
plt.ylabel("Percentage of transactions (%)", fontsize=14)

# To display the plot:
plt.show()

# %% [markdown]
# #### Observations: Fraudulent transactions occurred more frequently in the long tail of the distribution. It seems difficult to tell if a transaction is fraudulent just by looking at the amount alone.

# %% [markdown]
# #### Plot of Transactions in 48 Hours:

# %%
# To define bins for the histogram:
bins = np.linspace(0, 48, 48)

# To plot histogram for non-fraudulent transactions:
plt.hist(df_nonfraud.Time/(60*60), bins, alpha=1, label='Non-Fraud', color='lightblue')

# To plot histogram for fraudulent transactions:
plt.hist(df_fraud.Time/(60*60), bins, alpha=0.6, label='Fraud', color='red')

# To add legend:
plt.legend(loc='upper right')

# To set title and labels:
plt.title("Percentage of transactions by hour", fontsize=14)
plt.xlabel("Transaction time from first transaction in the dataset (hours)", fontsize=14)
plt.ylabel("Percentage of transactions (%)", fontsize=14)

# To display the plot:
plt.show()

# %% [markdown]
# #### Observations: There is a significant drop in normal transactions from hours 1 to 8 and again around hours 24 to 32, it appears that fraud tends to occur more frequently during the night.

# %% [markdown]
# ### Train Test Split:

# %%
# Putting the feature variable into X:

# To drop the 'Class' column to create the feature variable X:
X = df_card.drop(['Class'], axis=1)

# To display the first few rows of X to verify:
X.head(5)
# Out:
#     Time      V1      V2     V3      V4      V5      V6      V7      V8  \
# 0 0.0000 -1.3598 -0.0728 2.5363  1.3782 -0.3383  0.4624  0.2396  0.0987
# 1 0.0000  1.1919  0.2662 0.1665  0.4482  0.0600 -0.0824 -0.0788  0.0851
# 2 1.0000 -1.3584 -1.3402 1.7732  0.3798 -0.5032  1.8005  0.7915  0.2477
# 3 1.0000 -0.9663 -0.1852 1.7930 -0.8633 -0.0103  1.2472  0.2376  0.3774
# 4 2.0000 -1.1582  0.8777 1.5487  0.4030 -0.4072  0.0959  0.5929 -0.2705
#
#        V9     V10     V11     V12     V13     V14     V15     V16     V17  \
# 0  0.3638  0.0908 -0.5516 -0.6178 -0.9914 -0.3112  1.4682 -0.4704  0.2080
# 1 -0.2554 -0.1670  1.6127  1.0652  0.4891 -0.1438  0.6356  0.4639 -0.1148
# 2 -1.5147  0.2076  0.6245  0.0661  0.7173 -0.1659  2.3459 -2.8901  1.1100
# 3 -1.3870 -0.0550 -0.2265  0.1782  0.5078 -0.2879 -0.6314 -1.0596 -0.6841
# 4  0.8177  0.7531 -0.8228  0.5382  1.3459 -1.1197  0.1751 -0.4514 -0.2370
#
#       V18     V19     V20     V21     V22     V23     V24     V25     V26  \
# ...

# %%
# Putting the Target variable to y:

# To assign the 'Class' column from df_card to y as the target variable:
y = df_card['Class']

# %%
from sklearn.model_selection import StratifiedShuffleSplit

# To define the number of splits (kfold) and the split configuration:
kfold = 4
sss = StratifiedShuffleSplit(n_splits=kfold, test_size=0.3, random_state=9487)

# To iterate over the splits generated by Stratified Shuffle Split:
for train_index, test_index in sss.split(X, y):
    print("TRAIN:", train_index, "TEST:", test_index)

    # Splitting the data into training and test sets based on the indices:
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
# Out:
# TRAIN: [129141  91689 118805 ... 249655  69488 188068] TEST: [ 32603  71580 144362 ... 120664 260883 146701]
# TRAIN: [179661 129498 253513 ... 261021 275137 199709] TEST: [ 30193  96420  28988 ... 159837 243770  87245]
# TRAIN: [ 55609 250907 105943 ...  96700  41174 261733] TEST: [ 97330 182828 138896 ... 103047 280031 252278]
# TRAIN: [160541 270383   7914 ... 119570 142561 116811] TEST: [199984 152508 204491 ... 203781  88156  52492]

# %% [markdown]
# #### To check Skewness of data:

# %%
# To set the figure size:
plt.rcParams['figure.figsize'] = [12, 8]

# To plot a histogram of the 'Amount' column:
plt.hist(df_card['Amount'], edgecolor='black', bins=20, color='skyblue')

# To set the title and labels:
plt.title('Transaction Amount', fontsize=14)
plt.xlabel('Amount in USD', fontsize=14)
plt.ylabel('Count', fontsize=14)

# To display the plot:
plt.show()

# %%
from sklearn import preprocessing
from sklearn.preprocessing import PowerTransformer

# To initialize the PowerTransformer:
pt = preprocessing.PowerTransformer(copy=False)

# To fit and transform X using PowerTransformer:
PWTR_X = pt.fit_transform(X)

# %% [markdown]
# ### Building a Logistic Model:

# %% [markdown]
# Here, we will not focuse on accuracy, we will focuse in the recall score. Recall is important for capturing the maximum number of fraudulent transactions. Increasing recall may reduce precision, but in this case, incorrectly classifying a transaction as fraudulent when it isn't is not big issue.

# %% [markdown]
# ### Imbalanced Data Set:

# %% [markdown]
# ### Logistic Regression

# %% [markdown]
# #### Model 1 : Logistic Regression on Imbalanced Data:

# %%
from sklearn.model_selection import StratifiedShuffleSplit

# To define the number of splits (kfold) and the split configuration:
kfold = 4
sss = StratifiedShuffleSplit(n_splits=kfold, test_size=0.3, random_state=9487)

# To initialize PowerTransformer:
pt = preprocessing.PowerTransformer(copy=False)

# To fit and transform X using PowerTransformer:
PWTR_X = pt.fit_transform(X)

# To iterate over the splits generated by Stratified Shuffle Split:
for train_index, test_index in sss.split(PWTR_X, y):
    print("TRAIN:", train_index, "TEST:", test_index)

    # Splitting the data into training and test sets based on the indices:
    X_train, X_test = PWTR_X[train_index], PWTR_X[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
# Out:
# TRAIN: [129141  91689 118805 ... 249655  69488 188068] TEST: [ 32603  71580 144362 ... 120664 260883 146701]
# TRAIN: [179661 129498 253513 ... 261021 275137 199709] TEST: [ 30193  96420  28988 ... 159837 243770  87245]
# TRAIN: [ 55609 250907 105943 ...  96700  41174 261733] TEST: [ 97330 182828 138896 ... 103047 280031 252278]
# TRAIN: [160541 270383   7914 ... 119570 142561 116811] TEST: [199984 152508 204491 ... 203781  88156  52492]

# %%
from sklearn.linear_model import LogisticRegression

# To initialize a logistic regression model:
model_lr = LogisticRegression()

# To fit the logistic regression model to the training data:
model_lr.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
# To predict on the test data using the trained logistic regression model:
y_predicted = model_lr.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, roc_auc_score

# To print classification report:
print('Classification report:\n', classification_report(y_test, y_predicted))

# To print confusion matrix:
print('Confusion matrix:\n', confusion_matrix(y_true=y_test, y_pred=y_predicted))

# To print accuracy score:
print("Logistic Regression Accuracy: ", accuracy_score(y_test, y_predicted))

# To print ROC AUC score:
print('ROC AUC:', roc_auc_score(y_test, y_predicted))
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85295
#            1       0.86      0.60      0.71       148
#
#     accuracy                           1.00     85443
#    macro avg       0.93      0.80      0.85     85443
# weighted avg       1.00      1.00      1.00     85443
#
# Confusion matrix:
#  [[85280    15]
#  [   59    89]]
# Logistic Regression Accuracy:  0.999133925541004
# ROC AUC: 0.8005877455508148

# %%
import matplotlib.pyplot as plt

def plot_roc_curve(fpr, tpr, roc_auc):

    # To set figure size:
    plt.figure(figsize=(12, 8))

    # To plot the ROC curve:
    plt.plot(fpr, tpr, linewidth=2, label='AUC = %0.3f'% roc_auc, color='b')

    # To plot the diagonal line representing random guessing:
    plt.plot([0, 1], [0, 1], linestyle='--', linewidth=2, color='gray')

    # To set limits for x and y axes:
    plt.xlim([-0.01, 1])
    plt.ylim([0, 1.01])

    # To add a legend to the plot in the lower right corner:
    plt.legend(loc='lower right')

    # To set the title of the plot:
    plt.title('Receiver Operating Characteristic (ROC) Curve', fontsize=14)

    # To set labels for y-axis and x-axis:
    plt.ylabel('True Positive Rate (Sensitivity)', fontsize=14)
    plt.xlabel('False Positive Rate (1 - Specificity)', fontsize=14)

    # To display grid on the plot:
    plt.grid(True)

    # To display the plot:
    plt.show()

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# To compute ROC curve and ROC area for predictions:
fpr, tpr, thresholds = roc_curve(y_test, y_predicted)
roc_auc = roc_auc_score(y_test, y_predicted)

# %%
# To plot ROC curve using the computed values:
plt.rcParams['figure.figsize'] = [6, 6]
plot_roc_curve(fpr, tpr, roc_auc)

# %% [markdown]
# #### Model Performance Metrics:
#
# | Metric      | Score |
# |-------------|-------|
# | **Precision**  | 0.86  |
# | **Recall**     | 0.60 |
# | **F1-Score**   | 0.71  |
# | **Accuracy**   | 0.99  |
# | **ROC AUC**    | 0.80  |

# %% [markdown]
# ### Hyperparameter Tuning in Logisitic Regression:

# %% [markdown]
# #### Model 2 : Logistic Regression on Imbalanced Data with K-Fold and Hypertuning:

# %%
from imblearn.metrics import sensitivity_specificity_support

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV

# To set number of folds for cross-validation:
n_folds = 5

# To set parameters to tune:
params = {'C': [0.1, 0.5, 1, 2, 3, 4, 5, 10], 'penalty': ['l1', 'l2']}

# To initialize Logistic Regression model:
lrh = LogisticRegression()

# To setup GridSearchCV with logistic regression model, parameters, and cross-validation:
model_lrh = GridSearchCV(estimator=lrh,
                         param_grid=params,
                         scoring='roc_auc',
                         cv=n_folds,
                         n_jobs=-1,
                         verbose=1)

# %%
# To fit the GridSearchCV model to the training data:
model_lrh.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(cv=5, estimator=LogisticRegression(), n_jobs=-1,
#              param_grid={'C': [0.1, 0.5, 1, 2, 3, 4, 5, 10],
#                          'penalty': ['l1', 'l2']},
#              scoring='roc_auc', verbose=1)

# %%
pd.DataFrame(model_lrh.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0          0.0880        0.0143           0.0000          0.0000  0.1000
# 1          5.5373        0.5146           0.0778          0.0068  0.1000
# 2          0.1280        0.0063           0.0000          0.0000  0.5000
# 3          6.2339        0.3525           0.0681          0.0069  0.5000
# 4          0.1646        0.0128           0.0000          0.0000       1
# 5          6.0479        0.6189           0.0771          0.0110       1
# 6          0.1824        0.0189           0.0000          0.0000       2
# 7          6.0825        0.4007           0.0687          0.0084       2
# 8          0.1901        0.0296           0.0000          0.0000       3
# 9          6.0260        0.1454           0.0804          0.0101       3
# 10         0.1784        0.0212           0.0000          0.0000       4
# 11         6.7778        0.4855           0.0561          0.0102       4
# ...

# %%
# To print the best AUC score found by GridSearchCV:
print("Logistic Regression Best AUC:", model_lrh.best_score_)

# To print the best hyperparameters found by GridSearchCV:
print("Logistic Regression Best Hyperparameters:", model_lrh.best_params_)
# Out:
# Logistic Regression Best AUC: 0.9811351303398588
# Logistic Regression Best Hyperparameters: {'C': 0.1, 'penalty': 'l2'}

# %%
# To instantiate logistic regression model with best hyperparameters:
model_lrh_tuned = LogisticRegression(penalty='l2', C=0.1)

# %%
# To fit the tuned logistic regression model on the training data:
model_lrh_tuned.fit(X_train, y_train)

# To predict on the test data:
y_predicted = model_lrh_tuned.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, roc_auc_score

# To print classification report:
print('Classification Report:\n', classification_report(y_test, y_predicted))

# To print confusion matrix:
print('Confusion Matrix:\n', confusion_matrix(y_test, y_predicted))

# To print accuracy score:
print('Logistic Regression Accuracy:', accuracy_score(y_test, y_predicted))

# To print ROC AUC score:
print('ROC AUC Score:', roc_auc_score(y_test, y_predicted))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85295
#            1       0.85      0.58      0.69       148
#
#     accuracy                           1.00     85443
#    macro avg       0.93      0.79      0.85     85443
# weighted avg       1.00      1.00      1.00     85443
#
# Confusion Matrix:
#  [[85280    15]
#  [   62    86]]
# Logistic Regression Accuracy: 0.9990988144142879
# ROC AUC Score: 0.7904526104156797

# %%
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt

# To compute ROC curve and ROC AUC score:
fpr, tpr, thresholds = roc_curve(y_test, y_predicted)
roc_auc = roc_auc_score(y_test, y_predicted)

# To plot ROC curve using the previously defined plot_roc_curve function:
plt.rcParams['figure.figsize'] = [6, 6]
plot_roc_curve(fpr, tpr, roc_auc)

# %% [markdown]
# #### Model Performance Metrics:
#
# | Metric      | Score |
# |-------------|-------|
# | **Precision**  | 0.85  |
# | **Recall**     | 0.58  |
# | **F1-Score**   | 0.69  |
# | **Accuracy**   | 0.99  |
# | **ROC AUC**    | 0.79  |

# %% [markdown]
# ### Random Forest:

# %% [markdown]
# #### Model 3 : Random Forest on Imbalanced Data:

# %%
from sklearn.ensemble import RandomForestClassifier

# To initialize Random Forest classifier:
model_rfc = RandomForestClassifier(n_jobs=-1,  # To use all available CPU cores for parallel processing
                                   random_state=2018,  # Set random seed for reproducibility
                                   criterion='gini',  # Split criterion: 'gini' for Gini impurity, 'entropy' for information gain
                                   n_estimators=100,  # Number of trees in the forest
                                   verbose=False)  # Disable verbose output for training process

# %%
# To fit the Random Forest classifier on the training data:
model_rfc.fit(X_train, y_train)

# To predict on the test data:
y_predicted = model_rfc.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, roc_auc_score

# To print classification report:
print('Classification Report:\n', classification_report(y_test, y_predicted))

# To print confusion matrix:
print('Confusion Matrix:\n', confusion_matrix(y_test, y_predicted))

# To print accuracy score:
print('Accuracy Score:', accuracy_score(y_test, y_predicted))

# To print ROC AUC score:
print('ROC AUC Score:', roc_auc_score(y_test, y_predicted))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85295
#            1       0.94      0.70      0.80       148
#
#     accuracy                           1.00     85443
#    macro avg       0.97      0.85      0.90     85443
# weighted avg       1.00      1.00      1.00     85443
#
# Confusion Matrix:
#  [[85288     7]
#  [   44   104]]
# Accuracy Score: 0.999403110845827
# ROC AUC Score: 0.8513103172930829

# %%
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt

# To compute ROC curve and ROC AUC score:
fpr, tpr, thresholds = roc_curve(y_test, y_predicted)
roc_auc = roc_auc_score(y_test, y_predicted)

# To plot ROC curve:
plt.figure(figsize=(6, 6))
plt.plot(fpr, tpr, linewidth=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], linestyle='--', color='r', label='Random guess')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# #### Model Performance Metrics:
#
# | Metric      | Score |
# |-------------|-------|
# | **Precision**  | 0.94  |
# | **Recall**     | 0.70  |
# | **F1-Score**   | 0.80  |
# | **Accuracy**   | 0.99  |
# | **ROC AUC**    | 0.85  |

# %% [markdown]
# ### Hyperparameter Tuning on Random Forest:

# %% [markdown]
# #### Model 4 : Random Forest on Imbalanced Data with K-Fold and Hyperparamater Tuning:

# %%
from sklearn.model_selection import GridSearchCV  # Importing GridSearchCV
from sklearn.model_selection import StratifiedKFold  # Importing StratifiedKFold
from sklearn.metrics import accuracy_score  # Importing accuracy_score
from sklearn.model_selection import RandomizedSearchCV  # Importing RandomizedSearchCV

# %%
params = {
    'n_estimators': [200, 400],  # Number of trees in the forest
    'max_features': ['auto', 'sqrt', 'log2'],  # Number of features to consider for splitting at each node
    'max_depth' : [4, 5, 6, 7, 8],  # Maximum depth of the trees
    'criterion' : ['gini', 'entropy']  # Function to measure the quality of a split
}

# %%
from sklearn.model_selection import StratifiedKFold, RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier

# To define Stratified K Fold with 3 splits:
cross_val = StratifiedKFold(n_splits=3)

# To get the index iterator for cross-validation splits:
index_iterator = cross_val.split(X_train, y_train)

# To initialize a RandomForestClassifier:
clf = RandomForestClassifier()

# To setup RandomizedSearchCV for hyperparameter tuning:
clf_random = RandomizedSearchCV(estimator=clf,
                               param_distributions=params,  # Hyperparameters defined earlier
                               n_iter=50,  # Number of parameter settings sampled
                               cv=cross_val,  # Cross-validation strategy
                               verbose=2,  # Controls verbosity (2 for detailed messages)
                               random_state=42,  # Random seed for reproducibility
                               n_jobs=-1,  # Use all available CPU cores
                               scoring='roc_auc'  # Scoring metric for evaluation
                              )

# %%
# To fit the RandomizedSearchCV model on the training data:
clf_random.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# RandomizedSearchCV(cv=StratifiedKFold(n_splits=3, random_state=None, shuffle=False),
#                    estimator=RandomForestClassifier(), n_iter=50, n_jobs=-1,
#                    param_distributions={'criterion': ['gini', 'entropy'],
#                                         'max_depth': [4, 5, 6, 7, 8],
#                                         'max_features': ['auto', 'sqrt',
#                                                          'log2'],
#                                         'n_estimators': [200, 400]},
#                    random_state=42, scoring='roc_auc', verbose=2)

# %%
# To get the scores from RandomizedSearchCV:
scores = clf_random.cv_results_

# To display the scores as a DataFrame:
import pandas as pd
pd.DataFrame(scores).head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         0.0902        0.0102           0.0000          0.0000
# 1       426.0682        4.8499           2.8451          0.1846
# 2         0.1152        0.0208           0.0000          0.0000
# 3       878.9565       10.5167           3.5955          0.5488
# 4         0.1367        0.0044           0.0000          0.0000
#
#   param_n_estimators param_max_features param_max_depth param_criterion  \
# 0                200               auto               4            gini
# 1                400               log2               4            gini
# 2                200               auto               5         entropy
# 3                400               sqrt               6         entropy
# 4                400               auto               6            gini
#
#                                                                                   params  \
# ...

# %%
# To print the best score found during the randomized search:
print("Best ROC AUC Score: ", clf_random.best_score_)

# To print the best parameters found during the randomized search:
print("Best Parameters: ", clf_random.best_params_)

# To print the index of the best score found during the randomized search:
print("Index of Best Score: ", clf_random.best_index_)
# Out:
# Best ROC AUC Score:  0.9840433911827757
# Best Parameters:  {'n_estimators': 200, 'max_features': 'log2', 'max_depth': 7, 'criterion': 'entropy'}
# Index of Best Score:  14

# %%
from sklearn.ensemble import RandomForestClassifier

# To define the tuned RandomForestClassifier:
model_rfc_tuned = RandomForestClassifier(
    bootstrap=True,  # Whether bootstrap samples are used when building trees
    class_weight={0: 1, 1: 12},  # Weight of each class (0: non-fraud, 1: fraud)
    criterion='gini',  # Function to measure the quality of a split
    max_depth=5,  # Maximum depth of the trees
    max_features='sqrt',  # Number of features to consider when looking for the best split
    min_samples_leaf=10,  # Minimum number of samples required to be at a leaf node
    n_estimators=200,  # Number of trees in the forest
    n_jobs=-1,  # Number of jobs to run in parallel ( to use all available cores)
    random_state=5  # Random seed for reproducibility
)

# %%
# To fit the tuned RandomForestClassifier on the training data:
model_rfc_tuned.fit(X_train, y_train)

# to predict on the test data:
y_predicted = model_rfc_tuned.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, roc_auc_score

# To print classification report:
print('Classification report:\n', classification_report(y_test, y_predicted))

# To print confusion matrix:
print('Confusion matrix:\n', confusion_matrix(y_true=y_test, y_pred=y_predicted))

# To print accuracy score:
print("Accuracy: ", accuracy_score(y_test, y_predicted))

# To print ROC AUC score:
print('ROC AUC: ', roc_auc_score(y_test, y_predicted))
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85295
#            1       0.81      0.71      0.76       148
#
#     accuracy                           1.00     85443
#    macro avg       0.91      0.85      0.88     85443
# weighted avg       1.00      1.00      1.00     85443
#
# Confusion matrix:
#  [[85271    24]
#  [   43   105]]
# Accuracy:  0.9992158515033414
# ROC AUC:  0.8545890415299524

# %%
# To compute ROC curve and ROC area under the curve:
fpr, tpr, threshold = roc_curve(y_test, y_predicted)  # Calculate false positive rate, true positive rate, and thresholds
roc_auc = roc_auc_score(y_test, y_predicted)  # Calculate ROC AUC score

# To plot the ROC curve:
plt.rcParams['figure.figsize'] = [6, 6]  # Set the plot size
plot_roc_curve(fpr, tpr, roc_auc)  # Call function to plot ROC curve

# %% [markdown]
# #### Model Performance Metrics:
#
# | Metric      | Score |
# |-------------|-------|
# | **Precision**  | 0.81  |
# | **Recall**     | 0.71  |
# | **F1-Score**   | 0.76  |
# | **Accuracy**   | 0.99  |
# | **ROC AUC**    | 0.85  |

# %% [markdown]
# ### XG Boost:

# %% [markdown]
# #### Model 5 : XG Boost on Imbalanced Data:

# %%
# To initialize XGBoost classifier:
model_xgb = XGBClassifier()

# %%
# To fit the XGBoost classifier on the training data:
model_xgb.fit(X_train, y_train)

# To predict on the test data:
y_predicted = model_xgb.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, roc_auc_score

# To print classification report:
print('Classification report:\n', classification_report(y_test, y_predicted))

# To print confusion matrix:
print('Confusion matrix:\n', confusion_matrix(y_true=y_test, y_pred=y_predicted))

# To print accuracy score:
print("Accuracy: ", accuracy_score(y_test, y_predicted))

# To print ROC AUC score:
print('ROC AUC: ', roc_auc_score(y_test, y_predicted))
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85295
#            1       0.96      0.72      0.82       148
#
#     accuracy                           1.00     85443
#    macro avg       0.98      0.86      0.91     85443
# weighted avg       1.00      1.00      1.00     85443
#
# Confusion matrix:
#  [[85290     5]
#  [   41   107]]
# Accuracy:  0.9994616293903538
# ROC AUC:  0.8614571764448662

# %%
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt

# To compute ROC curve and ROC area under the curve:
fpr, tpr, threshold = roc_curve(y_test, y_predicted)  # Calculate false positive rate, true positive rate, and thresholds
roc_auc = roc_auc_score(y_test, y_predicted)  # Calculate ROC AUC score

# To plot the ROC curve:
plt.rcParams['figure.figsize'] = [12, 8]  # Set the plot size
plot_roc_curve(fpr, tpr, roc_auc)  # Call function to plot ROC curve

# %% [markdown]
# #### Model Performance Metrics:
#
# | Metric      | Score |
# |-------------|-------|
# | **Precision**  | 0.96  |
# | **Recall**     | 0.72  |
# | **F1-Score**   | 0.82  |
# | **Accuracy**   | 0.99  |
# | **ROC AUC**    | 0.86  |

# %% [markdown]
# ### Hyperparameter Tuning on XGB:

# %% [markdown]
# #### Model 6 : XGB on Imbalanced Data with K-Fold and Hyperparamater Tuning:

# %%
# To define hyperparameter grid for XGBoost tuning:
params = {
    'min_child_weight': [1, 5, 10],             # Minimum sum of instance weight (hessian) needed in a child node
    'gamma': [0.5, 1, 1.5, 2, 5],               # Minimum loss reduction required to make a further partition on a leaf node
    'subsample': [0.6, 0.8, 1.0],               # Subsample ratio of the training instances
    'colsample_bytree': [0.6, 0.8, 1.0],        # Subsample ratio of columns when constructing each tree
    'max_depth': [3, 4, 5]                      # Maximum depth of a tree
}

# %%
from sklearn.model_selection import StratifiedKFold, RandomizedSearchCV
from xgboost import XGBClassifier

# To define the number of splits for Stratified K Fold:
cross_val = StratifiedKFold(n_splits=5)

# To generate index iterator for splitting the data:
index_iterator = cross_val.split(X_train, y_train)

# To initialize XGBoost classifier with base parameters:
xgb_cross = XGBClassifier(learning_rate=0.02, n_estimators=100, objective='binary:logistic',
                          silent=True, nthread=1)

# To initialize RandomizedSearchCV for hyperparameter tuning:
xgb_random = RandomizedSearchCV(estimator=xgb_cross, param_distributions=params, n_iter=30, cv=cross_val,
                                verbose=2, random_state=42, n_jobs=-1, scoring='roc_auc')

# %%
# To fit the XGBoost model on the entire training data:
xgb_random.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# RandomizedSearchCV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=False),
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            callbacks=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None, device=None,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=False,
#                                            eval_metric=None, feature_types=None,
#                                            gamma=None, grow_policy=None,
#                                            impor...
#                                            min_child_weight=None, missing=nan,
# ...

# %%
# To scores of RandomizedSearchCV:
scores = xgb_random.cv_results_  # Retrieve results of randomized search
pd.DataFrame(scores).head()  # Display the first few rows of the results as a DataFrame
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         6.9617        0.4657           0.1036          0.0077
# 1         6.1418        0.6374           0.1265          0.0185
# 2         7.4343        0.6664           0.0972          0.0098
# 3         5.8833        0.4726           0.1207          0.0179
# 4         5.7412        0.4271           0.1135          0.0132
#
#   param_subsample param_min_child_weight param_max_depth param_gamma  \
# 0          0.8000                     10               4      1.5000
# 1          1.0000                      1               3           2
# 2          0.8000                     10               3           5
# 3          0.6000                     10               3           1
# 4          0.6000                     10               4           1
#
#   param_colsample_bytree  \
# 0                 0.6000
# 1                 0.8000
# 2                 1.0000
# 3                 0.6000
# 4                 0.6000
#
# ...

# %%
# To print the best score found by RandomizedSearchCV:
print(xgb_random.best_score_)

# To print the best parameters found by RandomizedSearchCV:
print(xgb_random.best_params_)

# To print the index (rank) of the best parameters found by RandomizedSearchCV:
print(xgb_random.best_index_)
# Out:
# 0.9515147774821262
# {'subsample': 0.6, 'min_child_weight': 10, 'max_depth': 4, 'gamma': 0.5, 'colsample_bytree': 0.6}
# 29

# %%
from xgboost import XGBClassifier

# To initialize XGBoost classifier with the best parameters:
model_xgb_tuned = XGBClassifier(min_child_weight=5,
                                gamma=1.5,
                                subsample=1.0,
                                colsample_bytree=0.6,
                                max_depth=5,
                                learning_rate=0.02,
                                n_estimators=100,
                                objective='binary:logistic',
                                silent=True,
                                nthread=1)

# %%
# To fit the tuned XGBoost model on Train data:
model_xgb_tuned.fit(X_train, y_train)

# To predict on Test data:
y_predicted = model_xgb_tuned.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, roc_auc_score

# To print classification report:
print('Classification report:\n', classification_report(y_test, y_predicted))

# To print confusion matrix:
print('Confusion matrix:\n', confusion_matrix(y_true=y_test, y_pred=y_predicted))

# To print accuracy score:
print("Accuracy: ", accuracy_score(y_test, y_predicted))

# To print ROC AUC score:
print('ROC AUC: ', roc_auc_score(y_test, y_predicted))
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85295
#            1       0.95      0.66      0.78       148
#
#     accuracy                           1.00     85443
#    macro avg       0.98      0.83      0.89     85443
# weighted avg       1.00      1.00      1.00     85443
#
# Confusion matrix:
#  [[85290     5]
#  [   51    97]]
# Accuracy:  0.9993445923013002
# ROC AUC:  0.8276733926610824

# %%
# To create true and false positive rates:
fpr, tpr, threshold = roc_curve(y_test, y_predicted)

# To calculate ROC AUC score:
roc_auc = roc_auc_score(y_test, y_predicted)

# To set the figure size for the ROC curve plot:
plt.rcParams['figure.figsize'] = [6, 6]

# To plot the ROC curve:
plot_roc_curve(fpr, tpr, roc_auc)

# %% [markdown]
# #### Model Performance Metrics:
#
# | Metric      | Score |
# |-------------|-------|
# | **Precision**  | 0.95  |
# | **Recall**     | 0.66  |
# | **F1-Score**   | 0.78  |
# | **Accuracy**   | 0.99  |
# | **ROC AUC**    | 0.82  |

# %% [markdown]
# ### Balanced Data Set:

# %%
from imblearn.over_sampling import RandomOverSampler, SMOTE, ADASYN

# To initialize resampling techniques:
ros = RandomOverSampler(random_state=5)  # RandomOverSampler for random oversampling
smote = SMOTE(random_state=5)            # SMOTE for Synthetic Minority Over-sampling Technique
adasyn = ADASYN(random_state=5)          # ADASYN for Adaptive Synthetic Sampling

# To resample training data using each technique:
X_train_ros, y_train_ros = ros.fit_resample(X_train, y_train)       # RandomOverSampler
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train) # SMOTE
X_train_adasyn, y_train_adasyn = adasyn.fit_resample(X_train, y_train) # ADASYN

# %% [markdown]
# ### Logistic Regression:

# %% [markdown]
# #### Model 7 : Logistic Regression on ROS Balanced Data:

# %%
# To fit logistic regression model on resampled training data:
from sklearn.linear_model import LogisticRegression

# To initialize logistic regression model:
model_lr = LogisticRegression()

# To train (fit) the model on the resampled training data:
model_lr.fit(X_train_ros, y_train_ros)

# To predict using the trained model on test data:
y_predicted = model_lr.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, roc_auc_score

# To print classification report:
print('Classification report:\n', classification_report(y_test, y_predicted))

# To print confusion matrix:
print('Confusion matrix:\n', confusion_matrix(y_true=y_test, y_pred=y_predicted))

# To calculate and print accuracy:
accuracy = accuracy_score(y_test, y_predicted)
print("Logistic Regression Accuracy: ", accuracy)

# To calculate and print ROC AUC score:
roc_auc = roc_auc_score(y_test, y_predicted)
print('ROC AUC : ', roc_auc)
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     85295
#            1       0.06      0.91      0.12       148
#
#     accuracy                           0.98     85443
#    macro avg       0.53      0.94      0.55     85443
# weighted avg       1.00      0.98      0.99     85443
#
# Confusion matrix:
#  [[83291  2004]
#  [   13   135]]
# Logistic Regression Accuracy:  0.9763936191379048
# ROC AUC :  0.9443336163996813

# %%
# To calculate ROC curve:
fpr, tpr, threshold = roc_curve(y_test, y_predicted)

# To calculate ROC AUC score:
roc_auc = roc_auc_score(y_test, y_predicted)

# To set the plot size:
plt.rcParams['figure.figsize'] = [6, 6]

# To plot the ROC curve:
plot_roc_curve(fpr, tpr, roc_auc)

# %% [markdown]
# #### Model Performance Metrics:
#
# | Metric      | Score |
# |-------------|-------|
# | **Precision**  | 0.06  |
# | **Recall**     | 0.91  |
# | **F1-Score**   | 0.12  |
# | **Accuracy**   | 0.97  |
# | **ROC AUC**    | 0.94  |

# %% [markdown]
# #### Model 8 : Logistic Regression on SMOTE Balanced Data:

# %%
# To import Logistic Regression from sklearn:
from sklearn.linear_model import LogisticRegression

# To initialize Logistic Regression model:
model_lr = LogisticRegression()

# To fit the Logistic Regression model on SMOTE resampled training data:
model_lr.fit(X_train_smote, y_train_smote)

# To make predictions on the test data:
y_predicted = model_lr.predict(X_test)

# %%
# To import evaluation metrics from sklearn:
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, roc_auc_score

# To print the classification report:
print('Classification report:\n', classification_report(y_test, y_predicted))

# To print the confusion matrix:
print('Confusion matrix:\n', confusion_matrix(y_true=y_test, y_pred=y_predicted))

# To print the accuracy score:
print("Logistic Regression Accuracy: ", accuracy_score(y_test, y_predicted))

# To calculate and printing the ROC AUC score:
print('ROC AUC : ', roc_auc_score(y_test, y_predicted))
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99     85295
#            1       0.06      0.91      0.11       148
#
#     accuracy                           0.97     85443
#    macro avg       0.53      0.94      0.55     85443
# weighted avg       1.00      0.97      0.99     85443
#
# Confusion matrix:
#  [[83107  2188]
#  [   14   134]]
# Logistic Regression Accuracy:  0.9742284329904146
# ROC AUC :  0.9398766284896772

# %%
# To import necessary libraries:
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt

# To calculate ROC curve:
fpr, tpr, threshold = roc_curve(y_test, y_predicted)

# To calculate ROC AUC score:
roc_auc = roc_auc_score(y_test, y_predicted)

# To set plot size:
plt.rcParams['figure.figsize'] = [6, 6]

# To plot ROC curve:
plot_roc_curve(fpr, tpr, roc_auc)

# %% [markdown]
# #### Model Performance Metrics:
#
# | Metric      | Score |
# |-------------|-------|
# | **Precision**  | 0.06  |
# | **Recall**     | 0.91  |
# | **F1-Score**   | 0.11  |
# | **Accuracy**   | 0.97  |
# | **ROC AUC**    | 0.93  |

# %% [markdown]
# #### Model 9 : Logistic Regression on ADASYN Balanced Data:

# %%
# To import Logistic Regression from sklearn:
from sklearn.linear_model import LogisticRegression

# To initialize Logistic Regression model:
model_lr = LogisticRegression()

# To fit the Logistic Regression model on ADASYN resampled training data:
model_lr.fit(X_train_adasyn, y_train_adasyn)

# To make predictions on the test data:
y_predicted = model_lr.predict(X_test)

# %%
# To import evaluation metrics from sklearn:
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, roc_auc_score

# To print the classification report:
print('Classification report:\n', classification_report(y_test, y_predicted))

# To print the confusion matrix:
print('Confusion matrix:\n', confusion_matrix(y_true=y_test, y_pred=y_predicted))

# To print the accuracy score:
print("Logistic Regression Accuracy: ", accuracy_score(y_test, y_predicted))

# To calculate and print the ROC AUC score:
print('ROC AUC : ', roc_auc_score(y_test, y_predicted))
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.92      0.96     85295
#            1       0.02      0.91      0.04       148
#
#     accuracy                           0.92     85443
#    macro avg       0.51      0.91      0.50     85443
# weighted avg       1.00      0.92      0.95     85443
#
# Confusion matrix:
#  [[78090  7205]
#  [   13   135]]
# Logistic Regression Accuracy:  0.9155226291211686
# ROC AUC :  0.9138453111062876

# %% [markdown]
# #### Model Performance Metrics:
#
# | Metric      | Score |
# |-------------|-------|
# | **Precision**  | 0.02  |
# | **Recall**     | 0.91  |
# | **F1-Score**   | 0.04  |
# | **Accuracy**   | 0.91  |
# | **ROC AUC**    | 0.91  |

# %% [markdown]
# ### Random Forest:

# %% [markdown]
# #### Model 10 : Random Forest on ROS Balanced Data:

# %%
# To import RandomForestClassifier from sklearn:
from sklearn.ensemble import RandomForestClassifier

# To instantiate RandomForestClassifier:
model_rfc = RandomForestClassifier(
    bootstrap=True,                  # Whether bootstrap samples are used
    class_weight={0:1, 1:12},        # Weight of each class, useful for imbalanced classes
    criterion='entropy',             # Split criterion ('gini' or 'entropy')
    max_depth=10,                    # Maximum depth of the trees
    min_samples_leaf=10,             # Minimum number of samples required to be at a leaf node
    n_estimators=20,                 # Number of trees in the forest
    n_jobs=-1,                       # Number of jobs to run in parallel (-1 uses all processors)
    random_state=5                   # Seed for random number generation for reproducibility
)

# %%
# To fit the RandomForestClassifier model on the resampled training data:
model_rfc.fit(X_train_ros, y_train_ros)

# To predict using the trained model on the test data:
y_predicted = model_rfc.predict(X_test)

# %%
# To print the classification report:
print('Classification report:\n', classification_report(y_test, y_predicted))

# To print the confusion matrix:
print('Confusion matrix:\n', confusion_matrix(y_true=y_test, y_pred=y_predicted))

# To print the accuracy score:
print("Logistic Regression Accuracy: ", accuracy_score(y_test, y_predicted))

# To print the ROC AUC score:
print('ROC AUC : ', roc_auc_score(y_test, y_predicted))
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85295
#            1       0.44      0.79      0.57       148
#
#     accuracy                           1.00     85443
#    macro avg       0.72      0.89      0.78     85443
# weighted avg       1.00      1.00      1.00     85443
#
# Confusion matrix:
#  [[85146   149]
#  [   31   117]]
# Logistic Regression Accuracy:  0.9978933323970366
# ROC AUC :  0.8943968310299866

# %% [markdown]
# #### Model Performance Metrics:
#
# | Metric      | Score |
# |-------------|-------|
# | **Precision**  | 0.44  |
# | **Recall**     | 0.79  |
# | **F1-Score**   | 0.57  |
# | **Accuracy**   | 0.99  |
# | **ROC AUC**    | 0.89  |

# %% [markdown]
# #### Model 11 : Random Forest on SMOTE Balanced Data:

# %%
# To fit the RandomForestClassifier model on the SMOTE-resampled training data:
model_rfc.fit(X_train_smote, y_train_smote)

# To predict using the trained model on the test data:
y_predicted = model_rfc.predict(X_test)

# %%
# To print the classification report:
print('Classification report:\n', classification_report(y_test, y_predicted))

# To print the confusion matrix:
print('Confusion matrix:\n', confusion_matrix(y_true=y_test, y_pred=y_predicted))

# To print the accuracy score:
print("Random Forest Classifier Accuracy: ", accuracy_score(y_test, y_predicted))

# To print the ROC AUC score:
print('ROC AUC : ', roc_auc_score(y_test, y_predicted))
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     85295
#            1       0.06      0.83      0.11       148
#
#     accuracy                           0.98     85443
#    macro avg       0.53      0.90      0.55     85443
# weighted avg       1.00      0.98      0.99     85443
#
# Confusion matrix:
#  [[83239  2056]
#  [   25   123]]
# Random Forest Classifier Accuracy:  0.9756445817679623
# ROC AUC :  0.9034882514262901

# %% [markdown]
# #### Model Performance Metrics:
#
# | Metric      | Score |
# |-------------|-------|
# | **Precision**  | 0.06  |
# | **Recall**     | 0.83  |
# | **F1-Score**   | 0.11  |
# | **Accuracy**   | 0.97  |
# | **ROC AUC**    | 0.90  |

# %% [markdown]
# #### Model 12 : Random Forest on ADASYN Balanced Data:

# %%
# To fit the RandomForestClassifier model on the ADASYN-resampled training data:
model_rfc.fit(X_train_adasyn, y_train_adasyn)

# To predict using the trained model on the test data:
y_predicted = model_rfc.predict(X_test)

# %%
# To print the classification report:
print('Classification report:\n', classification_report(y_test, y_predicted))

# To print the confusion matrix:
print('Confusion matrix:\n', confusion_matrix(y_true=y_test, y_pred=y_predicted))

# To print the accuracy score:
print("Random Forest Classifier Accuracy: ", accuracy_score(y_test, y_predicted))

# To print the ROC AUC score:
print('ROC AUC : ', roc_auc_score(y_test, y_predicted))
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98     85295
#            1       0.03      0.84      0.07       148
#
#     accuracy                           0.96     85443
#    macro avg       0.52      0.90      0.52     85443
# weighted avg       1.00      0.96      0.98     85443
#
# Confusion matrix:
#  [[81820  3475]
#  [   24   124]]
# Random Forest Classifier Accuracy:  0.9590487225401729
# ROC AUC :  0.8985484399928387

# %% [markdown]
# #### Model Performance Metrics:
#
# | Metric      | Score |
# |-------------|-------|
# | **Precision**  | 0.03  |
# | **Recall**     | 0.84  |
# | **F1-Score**   | 0.07  |
# | **Accuracy**   | 0.95  |
# | **ROC AUC**    | 0.89  |

# %% [markdown]
# ### Hyperparameter Tuning Random Forest on ROS Data:

# %% [markdown]
# #### Model 13 : Hyper Tuning  Model Random Forest on ROS Balanced Data:

# %%
# To define the parameter grid for Random Forest Classifier:
params = {
    'n_estimators': [200, 400],    # Number of trees in the forest
    'max_features': ['auto', 'sqrt', 'log2'],   # Number of features to consider when splitting
    'max_depth' : [4, 5, 6, 7, 8],  # Maximum depth of the trees
    'criterion' :['gini', 'entropy']  # Splitting criterion
}

# %%
# To define cross-validation strategy:
cross_val = StratifiedKFold(n_splits=3)

# To get index iterator for cross-validation splits:
index_iterator = cross_val.split(X_train_ros, y_train_ros)

# To instantiate a RandomForestClassifier:
clf = RandomForestClassifier()

# To create a RandomizedSearchCV object with specified parameters:
clf_random = RandomizedSearchCV(estimator=clf, param_distributions=params, n_iter=50, cv=cross_val,
                                verbose=2, random_state=42, n_jobs=-1, scoring='roc_auc')

# %%
clf_random.fit(X_train_ros, y_train_ros)
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# RandomizedSearchCV(cv=StratifiedKFold(n_splits=3, random_state=None, shuffle=False),
#                    estimator=RandomForestClassifier(), n_iter=50, n_jobs=-1,
#                    param_distributions={'criterion': ['gini', 'entropy'],
#                                         'max_depth': [4, 5, 6, 7, 8],
#                                         'max_features': ['auto', 'sqrt',
#                                                          'log2'],
#                                         'n_estimators': [200, 400]},
#                    random_state=42, scoring='roc_auc', verbose=2)

# %%
# To get the cross-validated results of the RandomizedSearchCV:
scores = clf_random.cv_results_

# To convert the results into a DataFrame and display the first few rows:
pd.DataFrame(scores).head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         0.4044        0.0751           0.0000          0.0000
# 1       497.0236        9.3460           6.7485          0.4837
# 2         0.3251        0.0044           0.0000          0.0000
# 3       980.9341       21.2505           7.4216          0.6770
# 4         0.3526        0.0272           0.0000          0.0000
#
#   param_n_estimators param_max_features param_max_depth param_criterion  \
# 0                200               auto               4            gini
# 1                400               log2               4            gini
# 2                200               auto               5         entropy
# 3                400               sqrt               6         entropy
# 4                400               auto               6            gini
#
#                                                                                   params  \
# ...

# %%
# To print the best score achieved during the RandomizedSearchCV:
print(clf_random.best_score_)

# To print the parameters that resulted in the best score:
print(clf_random.best_params_)

# To print the index of the best score in the results:
print(clf_random.best_index_)
# Out:
# 0.9999605417313604
# {'n_estimators': 400, 'max_features': 'sqrt', 'max_depth': 8, 'criterion': 'entropy'}
# 9

# %%
# To instantiate RandomForestClassifier with tuned hyperparameters:
model_rfc_tuned = RandomForestClassifier(bootstrap=True,
                                         class_weight={0: 1, 1: 12},  # Adjust class weights for imbalance
                                         criterion='entropy',  # Split criterion for decision trees
                                         max_depth=8,  # Maximum depth of trees
                                         max_features=None,  # Number of features to consider at each split
                                         n_estimators=200,  # Number of trees in the forest
                                         n_jobs=-1)  # Use all processors for parallel execution

# %%
# To fit the model on the resampled training data:
model_rfc_tuned.fit(X_train_ros, y_train_ros)

# To predict using the trained model on the test data:
y_predicted = model_rfc_tuned.predict(X_test)

# %%
# To import necessary libraries:
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, roc_auc_score

# To print the classification report:
print('Classification report:\n', classification_report(y_test, y_predicted))

# To print the confusion matrix:
print('Confusion matrix:\n', confusion_matrix(y_true = y_test, y_pred = y_predicted))

# To calculate and print the accuracy score:
print("Logistic Regression Accuracy: ", accuracy_score(y_test, y_predicted))

# To calculate and print the ROC AUC score:
print('ROC AUC : ', roc_auc_score(y_test, y_predicted))
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     85295
#            1       0.06      0.77      0.11       148
#
#     accuracy                           0.98     85443
#    macro avg       0.53      0.87      0.55     85443
# weighted avg       1.00      0.98      0.99     85443
#
# Confusion matrix:
#  [[83430  1865]
#  [   34   114]]
# Logistic Regression Accuracy:  0.9777746567887363
# ROC AUC :  0.8742024896107785

# %% [markdown]
# #### Model Performance Metrics:
#
# | Metric      | Score |
# |-------------|-------|
# | **Precision**  | 0.06  |
# | **Recall**     | 0.77  |
# | **F1-Score**   | 0.11  |
# | **Accuracy**   | 0.97  |
# | **ROC AUC**    | 0.87  |

# %% [markdown]
# ### XG Boost:

# %% [markdown]
# #### Model 14 : XGB on ROS Balanced Data:

# %%
model_xgb_ros = XGBClassifier()

# %%
# To fit the model on the training data:
model_xgb_ros.fit(X_train_ros, y_train_ros)

# To predict the labels on the test data:
y_predicted = model_xgb_ros.predict(X_test)

# %%
# Evaluation Metrics

# To print the classification report:
print('Classification report:\n', classification_report(y_test, y_predicted))

# To print the confusion matrix:
print('Confusion matrix:\n', confusion_matrix(y_true=y_test, y_pred=y_predicted))

# To calculate and print the accuracy score:
print("Accuracy Score: ", accuracy_score(y_test, y_predicted))

# To calculate and print the ROC AUC score:
print('ROC AUC Score: ', roc_auc_score(y_test, y_predicted))
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85295
#            1       0.89      0.73      0.80       148
#
#     accuracy                           1.00     85443
#    macro avg       0.95      0.86      0.90     85443
# weighted avg       1.00      1.00      1.00     85443
#
# Confusion matrix:
#  [[85282    13]
#  [   40   108]]
# Accuracy Score:  0.9993797034280163
# ROC AUC Score:  0.8647886587566522

# %% [markdown]
# #### Model Performance Metrics:
#
# | Metric      | Score |
# |-------------|-------|
# | **Precision**  | 0.89  |
# | **Recall**     | 0.73  |
# | **F1-Score**   | 0.80  |
# | **Accuracy**   | 0.99  |
# | **ROC AUC**    | 0.86  |

# %% [markdown]
# ### Hyperparameter Tuning on ROS Balanced Data:

# %% [markdown]
# #### Model 15 : Hyper Tuning XGB on ROS Balanced Data:

# %%
# To set parameter grid for XGBoost:
params = {
    'min_child_weight': [1, 5, 10],           # Minimum sum of instance weight (hessian) needed in a child
    'gamma': [0.5, 1, 1.5, 2, 5],             # Minimum loss reduction required to make a further partition on a leaf node
    'subsample': [0.6, 0.8, 1.0],             # Subsample ratio of the training instances
    'colsample_bytree': [0.6, 0.8, 1.0],      # Subsample ratio of columns when constructing each tree
    'max_depth': [3, 4, 5]                    # Maximum depth of a tree
}

# %%
from sklearn.model_selection import StratifiedKFold, RandomizedSearchCV
from xgboost import XGBClassifier

# To define the cross-validation strategy:
cross_val = StratifiedKFold(n_splits=4)

# To create an iterator for splitting the data:
index_iterator = cross_val.split(X_train_ros, y_train_ros)

# To define the base XGBoost classifier:
xgb_cross = XGBClassifier(learning_rate=0.02, n_estimators=100, objective='binary:logistic',
                          silent=True, nthread=1)

# To set up RandomizedSearchCV for hyperparameter tuning:
xgb_random = RandomizedSearchCV(estimator=xgb_cross, param_distributions=params, n_iter=30, cv=cross_val,
                                verbose=2, random_state=42, n_jobs=-1, scoring='roc_auc')

# %%
# To fit XGBoost on the oversampled training data:
xgb_random.fit(X_train_ros, y_train_ros)
# Out:
# Fitting 4 folds for each of 30 candidates, totalling 120 fits
# RandomizedSearchCV(cv=StratifiedKFold(n_splits=4, random_state=None, shuffle=False),
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            callbacks=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None, device=None,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=False,
#                                            eval_metric=None, feature_types=None,
#                                            gamma=None, grow_policy=None,
#                                            impor...
#                                            min_child_weight=None, missing=nan,
# ...

# %%
# To scores of RandomizedSearchCV:
scores = xgb_random.cv_results_  # Retrieve results of randomized search
pd.DataFrame(scores).head()      # Display the first few rows of the results as a DataFrame
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        17.3103        0.7654           0.3229          0.0186
# 1        14.4460        1.0367           0.3858          0.0820
# 2        16.0695        0.7669           0.3159          0.0079
# 3        16.0948        1.2578           0.3186          0.0217
# 4        17.2624        0.8607           0.3799          0.0439
#
#   param_subsample param_min_child_weight param_max_depth param_gamma  \
# 0          0.8000                     10               4      1.5000
# 1          1.0000                      1               3           2
# 2          0.8000                     10               3           5
# 3          0.6000                     10               3           1
# 4          0.6000                     10               4           1
#
#   param_colsample_bytree  \
# 0                 0.6000
# 1                 0.8000
# 2                 1.0000
# 3                 0.6000
# 4                 0.6000
#
# ...

# %%
# To print the best score found by RandomizedSearchCV:
print(xgb_random.best_score_)

# To print the best parameters found by RandomizedSearchCV:
print(xgb_random.best_params_)

# To print the index (rank) of the best parameters found by RandomizedSearchCV:
print(xgb_random.best_index_)
# Out:
# 0.9997585419081082
# {'subsample': 1.0, 'min_child_weight': 5, 'max_depth': 5, 'gamma': 1.5, 'colsample_bytree': 0.6}
# 5

# %%
from xgboost import XGBClassifier

# To define the XGBoost classifier with tuned hyperparameters:
model_xgb_tuned_ros = XGBClassifier(min_child_weight=5,
                                    gamma=1.5,
                                    subsample=1.0,
                                    colsample_bytree=0.6,
                                    max_depth=5)

# %%
# To fit the tuned XGBoost model on the resampled training data:
model_xgb_tuned_ros.fit(X_train_ros, y_train_ros)

# To predict the labels on the test data:
y_predicted = model_xgb_tuned_ros.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, roc_auc_score

# To print the classification report:
print('Classification report:\n', classification_report(y_test, y_predicted))

# To print the confusion matrix:
print('Confusion matrix:\n', confusion_matrix(y_true=y_test, y_pred=y_predicted))

# To calculate and print the accuracy score:
print("Accuracy Score: ", accuracy_score(y_test, y_predicted))

# To calculate and print the ROC AUC score:
print('ROC AUC Score: ', roc_auc_score(y_test, y_predicted))
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85295
#            1       0.88      0.78      0.83       148
#
#     accuracy                           1.00     85443
#    macro avg       0.94      0.89      0.91     85443
# weighted avg       1.00      1.00      1.00     85443
#
# Confusion matrix:
#  [[85280    15]
#  [   33   115]]
# Accuracy Score:  0.9994382219725431
# ROC AUC Score:  0.8884255833886526

# %% [markdown]
# #### Model Performance Metrics:
#
# | Metric      | Score |
# |-------------|-------|
# | **Precision**  | 0.88  |
# | **Recall**     | 0.78  |
# | **F1-Score**   | 0.83  |
# | **Accuracy**   | 0.99  |
# | **ROC AUC**    | 0.88  |

# %% [markdown]
# #### Model 16 : XGB on SMOTE Balanced Data:

# %%
model_xgb_smote = XGBClassifier()

# %%
# To fit the XGBoost model on the SMOTE resampled training data:
model_xgb_smote.fit(X_train_smote, y_train_smote)

# To predict the labels on the test data:
y_predicted = model_xgb_smote.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, roc_auc_score

# To print the classification report:
print('Classification report:\n', classification_report(y_test, y_predicted))

# To print the confusion matrix:
print('Confusion matrix:\n', confusion_matrix(y_true=y_test, y_pred=y_predicted))

# To calculate and print the accuracy score:
print("Accuracy Score: ", accuracy_score(y_test, y_predicted))

# To calculate and print the ROC AUC score:
print('ROC AUC Score: ', roc_auc_score(y_test, y_predicted))
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85295
#            1       0.83      0.76      0.79       148
#
#     accuracy                           1.00     85443
#    macro avg       0.91      0.88      0.90     85443
# weighted avg       1.00      1.00      1.00     85443
#
# Confusion matrix:
#  [[85272    23]
#  [   36   112]]
# Accuracy Score:  0.9993094811745842
# ROC AUC Score:  0.8782435521869251

# %% [markdown]
# #### Model Performance Metrics:
#
# | Metric      | Score |
# |-------------|-------|
# | **Precision**  | 0.83  |
# | **Recall**     | 0.76  |
# | **F1-Score**   | 0.79  |
# | **Accuracy**   | 0.99  |
# | **ROC AUC**    | 0.87  |

# %% [markdown]
# ### Hyperparameter Tuning on Smote Balanced Data:

# %% [markdown]
# #### Model 17 : Hyper Tuning XGB on SMOTE Balanced Data:

# %%
# To set parameter grid for XGBoost:
params = {
    'min_child_weight': [1, 5, 10, 15],         # Minimum sum of instance weight (hessian) needed in a child
    'gamma': [0.5, 1, 1.5, 2, 5, 8],            # Minimum loss reduction required to make a further partition on a leaf node
    'subsample': [0.6, 0.8, 1.0],               # Subsample ratio of the training instances
    'colsample_bytree': [0.6, 0.8, 1.0, 1.2],   # Subsample ratio of columns when constructing each tree
    'max_depth': [3, 4, 5, 6, 7]                # Maximum depth of a tree
}

# %%
from sklearn.model_selection import StratifiedKFold, RandomizedSearchCV
from xgboost import XGBClassifier

# To define the cross-validation strategy:
cross_val = StratifiedKFold(n_splits=5)

# To create an iterator for splitting the data:
index_iterator = cross_val.split(X_train_smote, y_train_smote)

# To define the base XGBoost classifier:
xgb_cross = XGBClassifier(learning_rate=0.02, n_estimators=100, objective='binary:logistic',
                          silent=True, nthread=1)

# To set up RandomizedSearchCV for hyperparameter tuning:
xgb_random = RandomizedSearchCV(estimator=xgb_cross, param_distributions=params, n_iter=40, cv=cross_val,
                                verbose=2, random_state=42, n_jobs=-1, scoring='roc_auc')

# %%
# To fit XGBoost on the SMOTE oversampled training data:
xgb_random.fit(X_train_smote, y_train_smote)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# RandomizedSearchCV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=False),
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            callbacks=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None, device=None,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=False,
#                                            eval_metric=None, feature_types=None,
#                                            gamma=None, grow_policy=None,
#                                            impor...
#                                            min_child_weight=None, missing=nan,
# ...

# %%
scores = xgb_random.cv_results_  # Retrieve results of randomized search
pd.DataFrame(scores).head()      # Display the first few rows of the results as a DataFrame
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        26.5295        1.4010           0.5277          0.1009
# 1        17.1372        1.5854           0.2981          0.0683
# 2        14.8945        0.6824           0.2814          0.0571
# 3        14.4127        0.9706           0.2814          0.0332
# 4        19.6679        0.8179           0.3090          0.0247
#
#   param_subsample param_min_child_weight param_max_depth param_gamma  \
# 0          0.6000                      1               7      1.5000
# 1          1.0000                      5               3           5
# 2          1.0000                     10               3           2
# 3          1.0000                      5               3           1
# 4          0.8000                      5               5           5
#
#   param_colsample_bytree  \
# 0                 0.6000
# 1                 0.8000
# 2                 0.8000
# 3                 0.6000
# 4                 0.8000
#
# ...

# %%
# To print the best score found by RandomizedSearchCV:
print(xgb_random.best_score_)

# To print the best parameters found by RandomizedSearchCV:
print(xgb_random.best_params_)

# To print the index (rank) of the best parameters found by RandomizedSearchCV:
print(xgb_random.best_index_)
# Out:
# 0.999681623618175
# {'subsample': 0.8, 'min_child_weight': 1, 'max_depth': 7, 'gamma': 2, 'colsample_bytree': 0.8}
# 10

# %%
from xgboost import XGBClassifier
# To define the XGBoost classifier with tuned hyperparameters for SMOTE data:
model_xgb_tuned_smote = XGBClassifier(min_child_weight=10,
                                      gamma=1.5,
                                      subsample=0.6,
                                      colsample_bytree=0.6,
                                      max_depth=5)

# %%
# To fit the tuned XGBoost model on the SMOTE resampled training data:
model_xgb_tuned_smote.fit(X_train_smote, y_train_smote)

# To predict the labels on the test data:
y_predicted = model_xgb_tuned_smote.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, roc_auc_score

# To print the classification report:
print('Classification report:\n', classification_report(y_test, y_predicted))

# To print the confusion matrix:
print('Confusion matrix:\n', confusion_matrix(y_true=y_test, y_pred=y_predicted))

# To calculate and print the accuracy score:
print("Accuracy Score: ", accuracy_score(y_test, y_predicted))

# To calculate and print the ROC AUC score:
print('ROC AUC Score: ', roc_auc_score(y_test, y_predicted))
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85295
#            1       0.66      0.81      0.73       148
#
#     accuracy                           1.00     85443
#    macro avg       0.83      0.91      0.86     85443
# weighted avg       1.00      1.00      1.00     85443
#
# Confusion matrix:
#  [[85233    62]
#  [   28   120]]
# Accuracy Score:  0.9989466661985184
# ROC AUC Score:  0.9050419608893142

# %% [markdown]
# #### Model Performance Metrics:
#
# | Metric      | Score |
# |-------------|-------|
# | **Precision**  | 0.66  |
# | **Recall**     | 0.81  |
# | **F1-Score**   | 0.73  |
# | **Accuracy**   | 0.99  |
# | **ROC AUC**    | 0.90  |

# %% [markdown]
# #### Model 18 : XGB on ADASYN Balanced Data:

# %%
model_xgb_adasyn = XGBClassifier()

# %%
# To fit the XGBoost model on the ADASYN resampled training data:
model_xgb_adasyn.fit(X_train_adasyn, y_train_adasyn)

# To predict the labels on the test data:
y_predicted = model_xgb_adasyn.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, roc_auc_score

# To print the classification report:
print('Classification report:\n', classification_report(y_test, y_predicted))

# To print the confusion matrix:
print('Confusion matrix:\n', confusion_matrix(y_true=y_test, y_pred=y_predicted))

# To calculate and print the accuracy score:
print("Accuracy Score: ", accuracy_score(y_test, y_predicted))

# To calculate and print the ROC AUC score:
print('ROC AUC Score: ', roc_auc_score(y_test, y_predicted))
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85295
#            1       0.75      0.78      0.76       148
#
#     accuracy                           1.00     85443
#    macro avg       0.88      0.89      0.88     85443
# weighted avg       1.00      1.00      1.00     85443
#
# Confusion matrix:
#  [[85257    38]
#  [   33   115]]
# Accuracy Score:  0.99916903666772
# ROC AUC Score:  0.8882907571971995

# %% [markdown]
# #### Model Performance Metrics:
#
# | Metric      | Score |
# |-------------|-------|
# | **Precision**  | 0.75  |
# | **Recall**     | 0.78  |
# | **F1-Score**   | 0.76  |
# | **Accuracy**   | 0.99  |
# | **ROC AUC**    | 0.88  |

# %% [markdown]
# #### Model 19: Hyperparameter Tuning on Adasyn Balanced Data:

# %%
# To set parameter grid for XGBoost:
params = {
    'min_child_weight': [1, 5, 10],         # Minimum sum of instance weight (hessian) needed in a child
    'gamma': [0.5, 1, 1.5, 2, 5],           # Minimum loss reduction required to make a further partition on a leaf node
    'subsample': [0.6, 0.8, 1.0],           # Subsample ratio of the training instances
    'colsample_bytree': [0.6, 0.8, 1.0],    # Subsample ratio of columns when constructing each tree
    'max_depth': [3, 4, 5]                  # Maximum depth of a tree
}

# %%
from sklearn.model_selection import StratifiedKFold, RandomizedSearchCV
from xgboost import XGBClassifier

# To define the cross-validation strategy:
cross_val = StratifiedKFold(n_splits=5)

# To create an iterator for splitting the data:
index_iterator = cross_val.split(X_train_adasyn, y_train_adasyn)

# To define the base XGBoost classifier:
xgb_cross = XGBClassifier(learning_rate=0.02, n_estimators=100, objective='binary:logistic',
                          silent=True, nthread=1)

# To set up RandomizedSearchCV for hyperparameter tuning:
xgb_random = RandomizedSearchCV(estimator=xgb_cross, param_distributions=params, n_iter=30, cv=cross_val,
                                verbose=2, random_state=42, n_jobs=-1, scoring='roc_auc')

# %%
# To fit XGBoost on the ADASYN oversampled training data:
xgb_random.fit(X_train_adasyn, y_train_adasyn)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# RandomizedSearchCV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=False),
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            callbacks=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None, device=None,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=False,
#                                            eval_metric=None, feature_types=None,
#                                            gamma=None, grow_policy=None,
#                                            impor...
#                                            min_child_weight=None, missing=nan,
# ...

# %%
scores = xgb_random.cv_results_  # Retrieve results of randomized search
pd.DataFrame(scores).head()      # Display the first few rows of the results as a DataFrame
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        17.9592        0.9563           0.2720          0.0078
# 1        14.2246        1.4973           0.2662          0.0207
# 2        15.9233        0.6342           0.2631          0.0073
# 3        15.8154        1.5346           0.2791          0.0116
# 4        18.5675        1.5212           0.2976          0.0135
#
#   param_subsample param_min_child_weight param_max_depth param_gamma  \
# 0          0.8000                     10               4      1.5000
# 1          1.0000                      1               3           2
# 2          0.8000                     10               3           5
# 3          0.6000                     10               3           1
# 4          0.6000                     10               4           1
#
#   param_colsample_bytree  \
# 0                 0.6000
# 1                 0.8000
# 2                 1.0000
# 3                 0.6000
# 4                 0.6000
#
# ...

# %%
# To print the best score found by RandomizedSearchCV:
print(xgb_random.best_score_)

# To print the best parameters found by RandomizedSearchCV:
print(xgb_random.best_params_)

# To print the index (rank) of the best parameters found by RandomizedSearchCV:
print(xgb_random.best_index_)
# Out:
# 0.9853187601905462
# {'subsample': 0.8, 'min_child_weight': 5, 'max_depth': 5, 'gamma': 5, 'colsample_bytree': 0.8}
# 9

# %%
from xgboost import XGBClassifier

# To define the XGBoost classifier with tuned hyperparameters for ADASYN data:
model_xgb_tuned_adasyn = XGBClassifier(min_child_weight=10,
                                       gamma=1.5,
                                       subsample=0.6,
                                       colsample_bytree=0.6,
                                       max_depth=5)

# %%
# To fit the tuned XGBoost model on the ADASYN resampled training data:
model_xgb_tuned_adasyn.fit(X_train_adasyn, y_train_adasyn)

# To predict the labels on the test data:
y_predicted = model_xgb_tuned_adasyn.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, roc_auc_score

# To print the classification report:
print('Classification report:\n', classification_report(y_test, y_predicted))

# To print the confusion matrix:
print('Confusion matrix:\n', confusion_matrix(y_true=y_test, y_pred=y_predicted))

# To calculate and print the accuracy score:
print("Accuracy Score: ", accuracy_score(y_test, y_predicted))

# To calculate and print the ROC AUC score:
print('ROC AUC Score: ', roc_auc_score(y_test, y_predicted))
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85295
#            1       0.57      0.82      0.68       148
#
#     accuracy                           1.00     85443
#    macro avg       0.79      0.91      0.84     85443
# weighted avg       1.00      1.00      1.00     85443
#
# Confusion matrix:
#  [[85204    91]
#  [   26   122]]
# Accuracy Score:  0.9986306660580738
# ROC AUC Score:  0.9116287194046734

# %% [markdown]
# #### Model Performance Metrics:
#
# | Metric      | Score |
# |-------------|-------|
# | **Precision**  | 0.57  |
# | **Recall**     | 0.82  |
# | **F1-Score**   | 0.68  |
# | **Accuracy**   | 0.99  |
# | **ROC AUC**    | 0.91  |

# %% [markdown]
# ### **Final Analysis:**

# %% [markdown]
# ### **Selecting Best Model:**

# %% [markdown]
# In summary, instead of focusing solely on overall accuracy across the entire dataset, our priority was to maximize the detection of fraud cases (recall) while keeping the associated costs in check (precision). We applied XGBoost on SMOTE-augmented data and achieved the best evaluation metrics.

# %% [markdown]
# ### **Prediction using the best model (model_xgb_smote):**

# %%
# To predict on the test data using the best model (model_xgb_smote):
y_predicted = model_xgb_smote.predict(X_test)

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# To compute ROC curve and ROC area for the predictions:
fpr, tpr, thresholds = roc_curve(y_test, y_predicted)
roc_auc = roc_auc_score(y_test, y_predicted)

# %%
from sklearn.metrics import classification_report, accuracy_score, roc_auc_score, confusion_matrix, roc_curve

# To print the classification report:
print('Classification report for XGBoost Smote:\n', classification_report(y_test, y_predicted))

# To calculate and print the accuracy score:
print("Accuracy Score: ", accuracy_score(y_test, y_predicted))

# To calculate and print the ROC AUC score:
print('ROC AUC Score: ', roc_auc_score(y_test, y_predicted))

# To print the confusion matrix:
print('Confusion matrix:\n', confusion_matrix(y_true=y_test, y_pred=y_predicted))

# To determine the optimal threshold based on the ROC curve:
fpr, tpr, thresholds = roc_curve(y_test, y_predicted)
threshold = thresholds[np.argmax(tpr - fpr)]
print("Optimal Threshold:", threshold)
# Out:
# Classification report for XGBoost Smote:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85295
#            1       0.83      0.76      0.79       148
#
#     accuracy                           1.00     85443
#    macro avg       0.91      0.88      0.90     85443
# weighted avg       1.00      1.00      1.00     85443
#
# Accuracy Score:  0.9993094811745842
# ROC AUC Score:  0.8782435521869251
# Confusion matrix:
#  [[85272    23]
#  [   36   112]]
# Optimal Threshold: 1.0

# %%
# To plot the ROC curve:
# To set figure size:
plt.rcParams['figure.figsize'] = [6, 6]

# to call function to plot ROC curve:
plot_roc_curve(fpr, tpr, roc_auc)

# %% [markdown]
# ### **Results:**
# | Metric       | Score |
# |--------------|-------|
# | Precision    | 0.83  |
# | Recall       | 0.76  |
# | F1-score     | 0.79  |
# | Accuracy     | 0.99  |
# | ROC AUC      | 0.87  |

# %% [markdown]
# ### Extracting Important Features:

# %%
# To define the target variable:
target = 'Class'

# To define the PCA components and additional columns:
pca_comp = [
    'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
    'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19',
    'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28',
    'Amount', 'Time'
]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# To create a DataFrame to store feature importances:
tmp = pd.DataFrame({'Feature': pca_comp, 'Feature importance': model_xgb_smote.feature_importances_})

# To sort features by importance in descending order:
tmp = tmp.sort_values(by='Feature importance', ascending=False)

# To plot feature importance with color:
plt.figure(figsize=(7, 4))
plt.title('Feature Importance', fontsize=14)
s = sns.barplot(x='Feature', y='Feature importance', data=tmp, palette='viridis')
s.set_xticklabels(s.get_xticklabels(), rotation=90)  # Rotate x-axis labels for better visibility
plt.show()

# %% [markdown]
# #### Observations: We found that variables such as V15 and V5, as identified by PCA, explain the majority of the variance. Therefore, we can focus on these variables to detect fraud effectively.

# %% [markdown]
# ### **Conclusion:**

# %% [markdown]
# <div align="justify"> This project demonstrates the power of machine learning in identifying fraudulent credit card transactions. By carefully handling data imbalance and testing multiple models with extensive hyperparameter tuning, we developed a robust fraud detection system that can significantly improve fraud prevention for banks. The final model provides a highly accurate solution that can be implemented by banks and financial institutions to reduce fraud, protect customer trust, and minimize financial losses. </div><br>
#
# <div align="justify">In a real-world application, this system can be further enhanced by integrating real-time transaction data and employing additional feature engineering techniques and further fine-tuning. Machine learning-based fraud detection systems like this are crucial for the financial sector to mitigate losses and maintain customer trust in an era of increasing digital transactions.</div>

# %% [markdown]
# ### **Tools and Libraries:**
# - Python, version 3
# - NumPy for numerical computations
# - Matplotlib and seaborn for data visualization
# - Pandas for data manipulation
# - Statsmodels for statistical modeling
# - Sklearn for machine learning tasks
# - Jupyter Notebook for interactive analysis

# %% [markdown]
# ### **References:**
# - Python documentations
# - ML/AI documentations
# - Stack Overflow
# - Kaggle
# - Medium AI Articles

# %% [markdown]
# ### **Contact:**
# Created by: https://github.com/Erkhanal - feel free to contact!
